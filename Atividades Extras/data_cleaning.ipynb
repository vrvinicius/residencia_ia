# %%
import pandas as pd

#config para mostrar todas as colunas da tabela
pd.set_option('display.max_columns', None)

# %%
#lendo o arquivo

df2021 = pd.read_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2021.csv', sep= ";", encoding= "ISO-8859-1")

# %%
df2021.head()
# Out:
#          id data_inversa   dia_semana   horario  uf   br     km  \
# 0  331730.0   2021-01-01  sexta-feira  05:30:00  SP  116    453
# 1  331804.0   2021-01-01  sexta-feira  08:05:00  AM  174    937
# 2  331815.0   2021-01-01  sexta-feira  10:10:00  CE  222  128,5
# 3  331823.0   2021-01-01  sexta-feira  12:30:00  RJ  493     18
# 4  331843.0   2021-01-01  sexta-feira  14:40:00  RJ  393    252
#
#         municipio                                     causa_acidente  \
# 0        REGISTRO           Reação tardia ou ineficiente do condutor
# 1          MANAUS           Reação tardia ou ineficiente do condutor
# 2         ITAPAJE                            Velocidade Incompatível
# 3            MAGE  Ingestão de álcool e/ou substâncias psicoativa...
# 4  BARRA DO PIRAI                                  Condutor Dormindo
#
#       tipo_acidente classificacao_acidente   fase_dia  sentido_via  \
# 0        Tombamento    Com Vítimas Feridas  Amanhecer    Crescente
# ...

# %%
df2021.shape
# Out:
# (64567, 30)

# %%
df[['data_inversa', 'horario', 'uf', 'br']].tail(10)
# Out:
#       data_inversa   horario  uf   br
# 64557   2021-09-26  20:00:00  PR  158
# 64558   2021-09-16  23:10:00  MG  365
# 64559   2021-05-03  19:37:00  GO  153
# 64560   2021-03-21  20:15:00  RO  364
# 64561   2021-06-27  19:10:00  MG  116
# 64562   2021-06-05  15:10:00  ES  101
# 64563   2021-10-26  09:15:00  BA  407
# 64564   2021-06-26  18:45:00  MG   40
# 64565   2021-10-31  10:40:00  AL  104
# 64566   2021-09-29  20:30:00  SE  101

# %%
# selecionando um intervalo específico de linhas no df
df[['horario','br']][150:172]
# Out:
#       horario   br
# 150  13:40:00  101
# 151  16:55:00  386
# 152  12:00:00  452
# 153  09:00:00  116
# 154  19:20:00  381
# 155  19:00:00  153
# 156  20:00:00  277
# 157  01:30:00  267
# 158  20:40:00  376
# 159  19:50:00  101
# 160  11:30:00  470
# 161  12:10:00  470
# 162  21:05:00  381
# 163  19:30:00  381
# 164  20:30:00  101
# 165  21:20:00  392
# 166  20:50:00  158
# 167  15:20:00  230
# 168  23:05:00  163
# 169  00:00:00  376
# 170  23:30:00  267
# 171  01:00:00  174

# %%
df.head(2)
# Out:
#          id data_inversa   dia_semana   horario  uf   br   km municipio  \
# 0  331730.0   2021-01-01  sexta-feira  05:30:00  SP  116  453  REGISTRO
# 1  331804.0   2021-01-01  sexta-feira  08:05:00  AM  174  937    MANAUS
#
#                              causa_acidente     tipo_acidente  \
# 0  Reação tardia ou ineficiente do condutor        Tombamento
# 1  Reação tardia ou ineficiente do condutor  Colisão traseira
#
#   classificacao_acidente   fase_dia sentido_via condicao_metereologica  \
# 0    Com Vítimas Feridas  Amanhecer   Crescente                Nublado
# 1                    NaN  Pleno dia   Crescente              Céu Claro
#
#   tipo_pista tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 0      Dupla       Curva      Não        1       0              1
# 1    Simples        Reta      Não        7       0              1
#
#    feridos_graves  ilesos  ignorados  feridos  veiculos      latitude  \
# ...

# %%
#renomeando colunas
df2021.rename(columns= {'municipio':'cidade'})
# Out:
#              id data_inversa    dia_semana   horario  uf   br     km  \
# 0      331730.0   2021-01-01   sexta-feira  05:30:00  SP  116    453
# 1      331804.0   2021-01-01   sexta-feira  08:05:00  AM  174    937
# 2      331815.0   2021-01-01   sexta-feira  10:10:00  CE  222  128,5
# 3      331823.0   2021-01-01   sexta-feira  12:30:00  RJ  493     18
# 4      331843.0   2021-01-01   sexta-feira  14:40:00  RJ  393    252
# ...         ...          ...           ...       ...  ..  ...    ...
# 64562  610856.0   2021-06-05        sábado  15:10:00  ES  101  178,4
# 64563  611724.0   2021-10-26   terça-feira  09:15:00  BA  407    202
# 64564  613470.0   2021-06-26        sábado  18:45:00  MG   40  551,7
# 64565  613705.0   2021-10-31       domingo  10:40:00  AL  104     74
# 64566  621196.0   2021-09-29  quarta-feira  20:30:00  SE  101     59
#
#                   cidade                                     causa_acidente  \
# ...

# %%
# renomeando uma série de colunas
df2021.rename(columns= {'municipio':'cidade', 'uf':'estado'}, inplace=True) #inplace para susbtituir no df as novas colunas

# %%
df2021.head(2)
# Out:
#          id data_inversa   dia_semana   horario estado   br   km    cidade  \
# 0  331730.0   2021-01-01  sexta-feira  05:30:00     SP  116  453  REGISTRO
# 1  331804.0   2021-01-01  sexta-feira  08:05:00     AM  174  937    MANAUS
#
#                              causa_acidente     tipo_acidente  \
# 0  Reação tardia ou ineficiente do condutor        Tombamento
# 1  Reação tardia ou ineficiente do condutor  Colisão traseira
#
#   classificacao_acidente   fase_dia sentido_via condicao_metereologica  \
# 0    Com Vítimas Feridas  Amanhecer   Crescente                Nublado
# 1                    NaN  Pleno dia   Crescente              Céu Claro
#
#   tipo_pista tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 0      Dupla       Curva      Não        1       0              1
# 1    Simples        Reta      Não        7       0              1
#
#    feridos_graves  ilesos  ignorados  feridos  veiculos      latitude  \
# ...

# %%
#adicionando coluna

df2021['total_feridos'] = df2021['feridos_leves'] + df2021['feridos_graves']

# %%
# deletando coluna

df2021.drop(columns= 'total_feridos', inplace= True)

# %%
df2021.head(2)
# Out:
#          id data_inversa   dia_semana   horario estado   br   km    cidade  \
# 0  331730.0   2021-01-01  sexta-feira  05:30:00     SP  116  453  REGISTRO
# 1  331804.0   2021-01-01  sexta-feira  08:05:00     AM  174  937    MANAUS
#
#                              causa_acidente     tipo_acidente  \
# 0  Reação tardia ou ineficiente do condutor        Tombamento
# 1  Reação tardia ou ineficiente do condutor  Colisão traseira
#
#   classificacao_acidente   fase_dia sentido_via condicao_metereologica  \
# 0    Com Vítimas Feridas  Amanhecer   Crescente                Nublado
# 1                    NaN  Pleno dia   Crescente              Céu Claro
#
#   tipo_pista tracado_via uso_solo  pessoas  mortos  feridos_leves  \
# 0      Dupla       Curva      Não        1       0              1
# 1    Simples        Reta      Não        7       0              1
#
#    feridos_graves  ilesos  ignorados  feridos  veiculos      latitude  \
# ...

# %%
# carregando demais arquivos
df2022 = pd.read_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2022.csv', sep= ",", encoding= "ISO-8859-1")
df2023 = pd.read_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2023.csv', sep= ";", encoding= "ISO-8859-1")
df2024 = pd.read_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2024.csv', sep= ",")

# %%
print(f'Dados 2021: {df2021.shape}')
print(f'Dados 2022: {df2022.shape}')
print(f'Dados 2023: {df2023.shape}')
print(f'Dados 2024: {df2024.shape}')
# Out:
# Dados 2021: (64567, 30)
# Dados 2022: (64606, 30)
# Dados 2023: (67766, 30)
# Dados 2024: (53950, 30)

# %%
#concatenando os dataframes

df_concat = pd.concat([df2021, df2022, df2023, df2024])
df_concat
# Out:
#              id data_inversa   dia_semana   horario  uf   br     km  \
# 0      331730.0   2021-01-01  sexta-feira  05:30:00  SP  116    453
# 1      331804.0   2021-01-01  sexta-feira  08:05:00  AM  174    937
# 2      331815.0   2021-01-01  sexta-feira  10:10:00  CE  222  128,5
# 3      331823.0   2021-01-01  sexta-feira  12:30:00  RJ  493     18
# 4      331843.0   2021-01-01  sexta-feira  14:40:00  RJ  393    252
# ...         ...          ...          ...       ...  ..  ...    ...
# 53945  635554.0   2024-09-27  sexta-feira  16:15:00  BA  324    615
# 53946  635630.0   2024-09-15      domingo  20:30:00  RJ  116    108
# 53947  635699.0   2024-08-13  terça-feira  16:22:00  AP  210      3
# 53948  635887.0   2024-09-21       sábado  18:50:00  PR  277    679
# 53949  636019.0   2024-09-15      domingo  19:00:00  PR  116      5
#
#             municipio                                     causa_acidente  \
# 0            REGISTRO           Reação tardia ou ineficiente do condutor
# ...

# %%
df_concat.shape
# Out:
# (250889, 30)

# %%
#salvando arquivo concatenado

df_concat.to_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2021_2024.csv', sep= ";", index= False)

# %%
df = pd.read_csv(r'C:\Users\vinicius_vieira\OneDrive - Sicredi\Residência IA\Atividades Extras\data\acidentes_prf_2021_2024.csv', sep= ";")

# %%
df
# Out:
#               id data_inversa   dia_semana   horario  uf   br     km  \
# 0       331730.0   2021-01-01  sexta-feira  05:30:00  SP  116    453
# 1       331804.0   2021-01-01  sexta-feira  08:05:00  AM  174    937
# 2       331815.0   2021-01-01  sexta-feira  10:10:00  CE  222  128,5
# 3       331823.0   2021-01-01  sexta-feira  12:30:00  RJ  493     18
# 4       331843.0   2021-01-01  sexta-feira  14:40:00  RJ  393    252
# ...          ...          ...          ...       ...  ..  ...    ...
# 250884  635554.0   2024-09-27  sexta-feira  16:15:00  BA  324    615
# 250885  635630.0   2024-09-15      domingo  20:30:00  RJ  116    108
# 250886  635699.0   2024-08-13  terça-feira  16:22:00  AP  210      3
# 250887  635887.0   2024-09-21       sábado  18:50:00  PR  277    679
# 250888  636019.0   2024-09-15      domingo  19:00:00  PR  116      5
#
#              municipio                                     causa_acidente  \
# ...

# %%
#verificando columas de um tipo especifico
int_columns = df.select_dtypes(include=['int64']).columns
int_columns
# Out:
# Index(['br', 'pessoas', 'mortos', 'feridos_leves', 'feridos_graves', 'ilesos',
#        'ignorados', 'feridos', 'veiculos'],
#       dtype='object')

# %%
# verificando nulos

df.isna().sum()
# Out:
# id                          0
# data_inversa                0
# dia_semana                  0
# horario                     0
# uf                          0
# br                          0
# km                          0
# municipio                   0
# causa_acidente              0
# tipo_acidente               0
# classificacao_acidente      4
# fase_dia                    0
# sentido_via                 0
# condicao_metereologica      0
# tipo_pista                  0
# tracado_via                 0
# uso_solo                    0
# pessoas                     0
# mortos                      0
# feridos_leves               0
# feridos_graves              0
# ilesos                      0
# ignorados                   0
# feridos                     0
# veiculos                    0
# latitude                    0
# longitude                   0
# regional                   23
# delegacia                  85
# uop                       219
# dtype: int64

# %%
# verificando duplicadas

df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 250884    False
# 250885    False
# 250886    False
# 250887    False
# 250888    False
# Length: 250889, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, data_inversa, dia_semana, horario, uf, br, km, municipio, causa_acidente, tipo_acidente, classificacao_acidente, fase_dia, sentido_via, condicao_metereologica, tipo_pista, tracado_via, uso_solo, pessoas, mortos, feridos_leves, feridos_graves, ilesos, ignorados, feridos, veiculos, latitude, longitude, regional, delegacia, uop]
# Index: []

# %%
#verificando tipos

df.dtypes
# Out:
# id                        float64
# data_inversa               object
# dia_semana                 object
# horario                    object
# uf                         object
# br                          int64
# km                         object
# municipio                  object
# causa_acidente             object
# tipo_acidente              object
# classificacao_acidente     object
# fase_dia                   object
# sentido_via                object
# condicao_metereologica     object
# tipo_pista                 object
# tracado_via                object
# uso_solo                   object
# pessoas                     int64
# mortos                      int64
# feridos_leves               int64
# feridos_graves              int64
# ilesos                      int64
# ignorados                   int64
# feridos                     int64
# veiculos                    int64
# latitude                   object
# longitude                  object
# ...

# %%
# alterando tipagem

df['id'] = df['id'].astype(int)

# %%
df.head()
# Out:
#        id data_inversa   dia_semana   horario  uf   br     km       municipio  \
# 0  331730   2021-01-01  sexta-feira  05:30:00  SP  116    453        REGISTRO
# 1  331804   2021-01-01  sexta-feira  08:05:00  AM  174    937          MANAUS
# 2  331815   2021-01-01  sexta-feira  10:10:00  CE  222  128,5         ITAPAJE
# 3  331823   2021-01-01  sexta-feira  12:30:00  RJ  493     18            MAGE
# 4  331843   2021-01-01  sexta-feira  14:40:00  RJ  393    252  BARRA DO PIRAI
#
#                                       causa_acidente     tipo_acidente  \
# 0           Reação tardia ou ineficiente do condutor        Tombamento
# 1           Reação tardia ou ineficiente do condutor  Colisão traseira
# 2                            Velocidade Incompatível        Tombamento
# 3  Ingestão de álcool e/ou substâncias psicoativa...   Colisão lateral
# 4                                  Condutor Dormindo   Colisão frontal
#
# ...

# %%
# categorizando coluna de data

df['data_inversa'] = pd.to_datetime(df['data_inversa'])

# %%
df.head()
# Out:
#        id data_inversa   dia_semana   horario  uf   br     km       municipio  \
# 0  331730   2021-01-01  sexta-feira  05:30:00  SP  116    453        REGISTRO
# 1  331804   2021-01-01  sexta-feira  08:05:00  AM  174    937          MANAUS
# 2  331815   2021-01-01  sexta-feira  10:10:00  CE  222  128,5         ITAPAJE
# 3  331823   2021-01-01  sexta-feira  12:30:00  RJ  493     18            MAGE
# 4  331843   2021-01-01  sexta-feira  14:40:00  RJ  393    252  BARRA DO PIRAI
#
#                                       causa_acidente     tipo_acidente  \
# 0           Reação tardia ou ineficiente do condutor        Tombamento
# 1           Reação tardia ou ineficiente do condutor  Colisão traseira
# 2                            Velocidade Incompatível        Tombamento
# 3  Ingestão de álcool e/ou substâncias psicoativa...   Colisão lateral
# 4                                  Condutor Dormindo   Colisão frontal
#
# ...

# %%
# tratando coluna km

df['km'] = df['km'].str.replace(',', '.')
df['km'] = df['km'].astype(float)

# %%
df.dtypes
# Out:
# id                                 int64
# data_inversa              datetime64[ns]
# dia_semana                        object
# horario                           object
# uf                                object
# br                                 int64
# km                               float64
# municipio                         object
# causa_acidente                    object
# tipo_acidente                     object
# classificacao_acidente            object
# fase_dia                          object
# sentido_via                       object
# condicao_metereologica            object
# tipo_pista                        object
# tracado_via                       object
# uso_solo                          object
# pessoas                            int64
# mortos                             int64
# feridos_leves                      int64
# feridos_graves                     int64
# ilesos                             int64
# ignorados                          int64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import cartopy.crs as ccrs

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250889 entries, 0 to 250888
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      250889 non-null  int64
#  1   data_inversa            250889 non-null  datetime64[ns]
#  2   dia_semana              250889 non-null  object
#  3   horario                 250889 non-null  object
#  4   uf                      250889 non-null  object
#  5   br                      250889 non-null  int64
#  6   km                      250889 non-null  float64
#  7   municipio               250889 non-null  object
#  8   causa_acidente          250889 non-null  object
#  9   tipo_acidente           250889 non-null  object
#  10  classificacao_acidente  250885 non-null  object
#  11  fase_dia                250889 non-null  object
#  12  sentido_via             250889 non-null  object
# ...

# %%
df.describe()
# Out:
#                   id                   data_inversa             br  \
# count  250889.000000                         250889  250889.000000
# mean   487171.674055  2022-12-04 07:08:12.126797056     210.154291
# min    331693.000000            2021-01-01 00:00:00       0.000000
# 25%    404481.000000            2021-12-21 00:00:00     101.000000
# 50%    493667.000000            2022-12-12 00:00:00     158.000000
# 75%    563207.000000            2023-11-19 00:00:00     324.000000
# max    636019.000000            2024-09-30 00:00:00     498.000000
# std     88135.406738                            NaN     130.175294
#
#                   km        pessoas         mortos  feridos_leves  \
# count  250889.000000  250889.000000  250889.000000  250889.000000
# mean      258.669085       2.563137       0.083631       0.859133
# min         0.000000       1.000000       0.000000       0.000000
# 25%        77.000000       2.000000       0.000000       0.000000
# ...

# %%
df.head()
# Out:
#        id data_inversa   dia_semana   horario  uf   br     km       municipio  \
# 0  331730   2021-01-01  sexta-feira  05:30:00  SP  116  453.0        REGISTRO
# 1  331804   2021-01-01  sexta-feira  08:05:00  AM  174  937.0          MANAUS
# 2  331815   2021-01-01  sexta-feira  10:10:00  CE  222  128.5         ITAPAJE
# 3  331823   2021-01-01  sexta-feira  12:30:00  RJ  493   18.0            MAGE
# 4  331843   2021-01-01  sexta-feira  14:40:00  RJ  393  252.0  BARRA DO PIRAI
#
#                                       causa_acidente     tipo_acidente  \
# 0           Reação tardia ou ineficiente do condutor        Tombamento
# 1           Reação tardia ou ineficiente do condutor  Colisão traseira
# 2                            Velocidade Incompatível        Tombamento
# 3  Ingestão de álcool e/ou substâncias psicoativa...   Colisão lateral
# 4                                  Condutor Dormindo   Colisão frontal
#
# ...
